# %%
import pandas as pd

# %%
raw_data = pd.read_csv('C:/Users/82109/Desktop/Study/AI Basic Course/data_assignment.txt',sep='\t')
raw_data.head()
# Out:
#      기간  대분류   분류  운동을 할 충분한 시간이 없어서  함께 운동을 할 사람이 없어서  운동을 할 만한 장소가 없어서  \
# 0  2019  서울시  서울시               46.8               5.0               4.3
# 1  2019   성별   남자               52.4               4.4               4.9
# 2  2019   성별   여자               42.5               5.6               3.9
# 3  2019  연령별  10대               55.3               4.8               3.9
# 4  2019  연령별  20대               46.0               4.2               4.5
#
#    운동을 싫어해서  운동을 할 충분한 비용이 없어서   기타
# 0      37.3                5.2  1.4
# 1      32.4                4.9  1.1
# 2      41.0                5.4  1.7
# 3      32.6                3.5    -
# 4      38.8                6.4  0.1

# %%
raw_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   기간                 52 non-null     int64
#  1   대분류                52 non-null     object
#  2   분류                 52 non-null     object
#  3   운동을 할 충분한 시간이 없어서  52 non-null     float64
#  4   함께 운동을 할 사람이 없어서   52 non-null     float64
#  5   운동을 할 만한 장소가 없어서   52 non-null     float64
#  6   운동을 싫어해서           52 non-null     float64
#  7   운동을 할 충분한 비용이 없어서  52 non-null     float64
#  8   기타                 52 non-null     object
# dtypes: float64(5), int64(1), object(3)
# memory usage: 3.8+ KB

# %%
raw_data[raw_data['대분류'] == '성별']
# Out:
#      기간 대분류  분류  운동을 할 충분한 시간이 없어서  함께 운동을 할 사람이 없어서  운동을 할 만한 장소가 없어서  \
# 1  2019  성별  남자               52.4               4.4               4.9
# 2  2019  성별  여자               42.5               5.6               3.9
#
#    운동을 싫어해서  운동을 할 충분한 비용이 없어서   기타
# 1      32.4                4.9  1.1
# 2      41.0                5.4  1.7

# %%
raw_data.drop(['기간'],axis=1).head()
# Out:
#    대분류   분류  운동을 할 충분한 시간이 없어서  함께 운동을 할 사람이 없어서  운동을 할 만한 장소가 없어서  운동을 싫어해서  \
# 0  서울시  서울시               46.8               5.0               4.3      37.3
# 1   성별   남자               52.4               4.4               4.9      32.4
# 2   성별   여자               42.5               5.6               3.9      41.0
# 3  연령별  10대               55.3               4.8               3.9      32.6
# 4  연령별  20대               46.0               4.2               4.5      38.8
#
#    운동을 할 충분한 비용이 없어서   기타
# 0                5.2  1.4
# 1                4.9  1.1
# 2                5.4  1.7
# 3                3.5    -
# 4                6.4  0.1

# %%
raw_data.drop(['기간'],axis=1,inplace=True)
raw_data.head()
# Out:
#    대분류   분류  운동을 할 충분한 시간이 없어서  함께 운동을 할 사람이 없어서  운동을 할 만한 장소가 없어서  운동을 싫어해서  \
# 0  서울시  서울시               46.8               5.0               4.3      37.3
# 1   성별   남자               52.4               4.4               4.9      32.4
# 2   성별   여자               42.5               5.6               3.9      41.0
# 3  연령별  10대               55.3               4.8               3.9      32.6
# 4  연령별  20대               46.0               4.2               4.5      38.8
#
#    운동을 할 충분한 비용이 없어서   기타
# 0                5.2  1.4
# 1                4.9  1.1
# 2                5.4  1.7
# 3                3.5    -
# 4                6.4  0.1

# %%
raw_data = raw_data[raw_data['대분류'] == '연령별']
raw_data
# Out:
#    대분류      분류  운동을 할 충분한 시간이 없어서  함께 운동을 할 사람이 없어서  운동을 할 만한 장소가 없어서  \
# 3  연령별     10대               55.3               4.8               3.9
# 4  연령별     20대               46.0               4.2               4.5
# 5  연령별     30대               59.9               5.2               2.9
# 6  연령별     40대               54.1               3.9               2.9
# 7  연령별     50대               46.1               6.2               4.5
# 8  연령별  60대 이상               26.6               6.0               6.6
#
#    운동을 싫어해서  운동을 할 충분한 비용이 없어서   기타
# 3      32.6                3.5    -
# 4      38.8                6.4  0.1
# 5      27.3                4.5  0.2
# 6      35.5                3.3  0.4
# 7      36.8                5.6  0.8
# 8      48.7                6.6  5.6

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

from matplotlib import font_manager, rc
plt.rcParams['axes.unicode_minus'] = False

f_path = 'C:/WINDOWS/FONTS/gulim.ttc'
font_name = font_manager.FontProperties(fname=f_path).get_name()
rc('font',family = font_name)

# %%
plt.figure(figsize=(10,8))
raw_data['운동을 할 충분한 시간이 없어서'].plot.pie()
plt.show()

# %%
raw_data.set_index('분류',inplace=True)
raw_data.head()
# Out:
#      대분류  운동을 할 충분한 시간이 없어서  함께 운동을 할 사람이 없어서  운동을 할 만한 장소가 없어서  운동을 싫어해서  \
# 분류
# 10대  연령별               55.3               4.8               3.9      32.6
# 20대  연령별               46.0               4.2               4.5      38.8
# 30대  연령별               59.9               5.2               2.9      27.3
# 40대  연령별               54.1               3.9               2.9      35.5
# 50대  연령별               46.1               6.2               4.5      36.8
#
#      운동을 할 충분한 비용이 없어서   기타
# 분류
# 10대                3.5    -
# 20대                6.4  0.1
# 30대                4.5  0.2
# 40대                3.3  0.4
# 50대                5.6  0.8

# %%
plt.figure(figsize=(10,8))
raw_data['운동을 할 충분한 시간이 없어서'].plot.pie()
plt.show()

# %%
raw_data['함께 운동을 할 사람이 없어서'] = raw_data['함께 운동을 할 사람이 없어서'].astype('float')
raw_data.info()

# %%
plt.figure(figsize=(10,8))
raw_data['함께 운동을 할 사람이 없어서'].plot.pie(explode=[0,0.02])
plt.show()

# %%
fig, ax = plt.subplots(1,2, figsize=(16,8))

raw_data['운동을 할 충분한 시간이 없어서'].plot.bar(ax=ax[0])

ax[0].set_title('운동을 할 충분한 시간이 없어서')
ax[0].set_ylabel('')

raw_data['운동을 싫어해서'].plot.bar(ax=ax[1])

ax[1].set_title('운동을 싫어해서')
ax[1].set_ylabel('')

plt.show()
