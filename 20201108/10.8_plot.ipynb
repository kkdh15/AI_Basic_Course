# %%
import pandas as pd

# %%
df = pd.read_excel('./test.xlsx')
df.head
# Out:
# <bound method NDFrame.head of     활동실적별(1)  활동실적별(2)    2017    2018    2019
# 0   출동건수 (건)        소계  805194  837628  893606
# 1   구조건수 (건)        소계  655485  663526  719228
# 2   구조인원 (명)        소계  115595  104335   99922
# 3  미처리건수 (건)        소계  149709  174102  174378
# 4       1일평균        소계    2206       -       -
# 5        NaN  출동건수 (건)    2206    2295       -
# 6        NaN  구조건수 (건)    1796    1818    1970
# 7        NaN  구조인원 (명)     317     286     274>

# %%
df_total = df.iloc[[0,7],3:]
df_total
# Out:
#      2018    2019
# 0  837628  893606
# 7     286     274

# %%
df_total.columns.map(int)
# Out:
# Int64Index([2018, 2019], dtype='int64')

# %%
df_total
# Out:
#      2018    2019
# 0  837628  893606
# 7     286     274

# %%
df_total.plot()
# Out:
# <AxesSubplot:>

# %%
df_total.plot(kind = 'bar')
# Out:
# <AxesSubplot:>

# %%
df_mpg = pd.read_csv('./mpg.csv')
df_mpg
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0          8         307.0       130.0    3504          12.0
# 1    15.0          8         350.0       165.0    3693          11.5
# 2    18.0          8         318.0       150.0    3436          11.0
# 3    16.0          8         304.0       150.0    3433          12.0
# 4    17.0          8         302.0       140.0    3449          10.5
# ..    ...        ...           ...         ...     ...           ...
# 393  27.0          4         140.0        86.0    2790          15.6
# 394  44.0          4          97.0        52.0    2130          24.6
# 395  32.0          4         135.0        84.0    2295          11.6
# 396  28.0          4         120.0        79.0    2625          18.6
# 397  31.0          4         119.0        82.0    2720          19.4
#
#      model_year  origin                       name
# 0            70     usa  chevrolet chevelle malibu
# ...

# %%
df_mpg.plot(title = 'mpg vs Weight', x='weight',y='mpg',kind='scatter')
# Out:
# <AxesSubplot:title={'center':'mpg vs Weight'}, xlabel='weight', ylabel='mpg'>

# %%
df_mpg
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0          8         307.0       130.0    3504          12.0
# 1    15.0          8         350.0       165.0    3693          11.5
# 2    18.0          8         318.0       150.0    3436          11.0
# 3    16.0          8         304.0       150.0    3433          12.0
# 4    17.0          8         302.0       140.0    3449          10.5
# ..    ...        ...           ...         ...     ...           ...
# 393  27.0          4         140.0        86.0    2790          15.6
# 394  44.0          4          97.0        52.0    2130          24.6
# 395  32.0          4         135.0        84.0    2295          11.6
# 396  28.0          4         120.0        79.0    2625          18.6
# 397  31.0          4         119.0        82.0    2720          19.4
#
#      model_year  origin                       name
# 0            70     usa  chevrolet chevelle malibu
# ...

# %%
df_mpg.plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
df_mpg.plot(kind='barh')
# Out:
# <AxesSubplot:>

# %%
 df_mpg['mpg'].plot(kind='box')
# Out:
# <AxesSubplot:>

# %%
df_mpg['mpg'].describe()
# Out:
# count    398.000000
# mean      23.514573
# std        7.815984
# min        9.000000
# 25%       17.500000
# 50%       23.000000
# 75%       29.000000
# max       46.600000
# Name: mpg, dtype: float64
