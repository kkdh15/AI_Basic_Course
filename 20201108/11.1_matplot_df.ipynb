# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
plt.plot([1,2,3,4],[1,7,2,5])
plt.ylabel('some numbers')
plt.show()

# %%
df = pd.read_excel('./move.xlsx')
df.head()
# Out:
#    행정구역(시군구)별  이동규모별     2001     2002     2003     2004     2005     2006  \
# 0  행정구역(시군구)별  이동규모별  순이동 (건)  순이동 (건)  순이동 (건)  순이동 (건)  순이동 (건)  순이동 (건)
# 1          전국      계        0        0        0        0        0        0
# 2       서울특별시      계   -10031   -13003   -10568   -10493    -9106     3507
# 3       부산광역시      계   -26654   -30381   -29290   -24545   -27022   -28309
# 4       대구광역시      계    -9932    -8386    -5909   -10977   -15948   -19827
#
#       2007     2008  ...     2010     2011     2012     2013     2014  \
# 0  순이동 (건)  순이동 (건)  ...  순이동 (건)  순이동 (건)  순이동 (건)  순이동 (건)  순이동 (건)
# 1        0        0  ...        0        0        0        0        0
# 2    -4484    -9770  ...   -43713   -44534   -35079   -34584   -28750
# 3   -28272   -24834  ...   -21142   -19222   -17890   -15121   -11926
# 4   -14487   -12823  ...   -10824   -11383    -9897    -9943   -13115
#
#       2015     2016     2017     2018     2019
# ...

# %%
df = df.replace('-', 0)

# %%
df
# Out:
#     행정구역(시군구)별  이동규모별     2001     2002     2003     2004     2005     2006  \
# 0   행정구역(시군구)별  이동규모별  순이동 (건)  순이동 (건)  순이동 (건)  순이동 (건)  순이동 (건)  순이동 (건)
# 1           전국      계        0        0        0        0        0        0
# 2        서울특별시      계   -10031   -13003   -10568   -10493    -9106     3507
# 3        부산광역시      계   -26654   -30381   -29290   -24545   -27022   -28309
# 4        대구광역시      계    -9932    -8386    -5909   -10977   -15948   -19827
# 5        인천광역시      계     5846     9495    -2698     1077     5096     7333
# 6        광주광역시      계    -2043     1101    -8423    -4264    -6699    -3712
# 7        대전광역시      계     4212     4650     4013     1317     2161     -233
# 8        울산광역시      계     4976     2607     2348     2790      936     -283
# 9      세종특별자치시      계        0        0        0        0        0        0
# 10         경기도      계   120897   164922   132000   115328   110863    89801
# ...

# %%
df_x = df.iloc[3:]
df_x.head()
# Out:
#   행정구역(시군구)별 이동규모별    2001    2002    2003    2004    2005    2006    2007  \
# 3      부산광역시     계  -26654  -30381  -29290  -24545  -27022  -28309  -28272
# 4      대구광역시     계   -9932   -8386   -5909  -10977  -15948  -19827  -14487
# 5      인천광역시     계    5846    9495   -2698    1077    5096    7333   12313
# 6      광주광역시     계   -2043    1101   -8423   -4264   -6699   -3712   -4744
# 7      대전광역시     계    4212    4650    4013    1317    2161    -233   -2526
#
#      2008  ...    2010    2011    2012    2013    2014    2015    2016  \
# 3  -24834  ...  -21142  -19222  -17890  -15121  -11926  -12412  -14722
# 4  -12823  ...  -10824  -11383   -9897   -9943  -13115  -10277   -8839
# 5    4369  ...     986   11527   13223   10897    3661    3617    3717
# 6   -1354  ...     713    -632   -2155   -2804   -2947   -7210   -5696
# 7   -4356  ...    -418    1358     242    -226   -3860   -8121   -4042
#
#      2017    2018    2019
# 3  -16425  -20656  -17591
# 4   -9846  -10811  -18294
# ...

# %%
df_seoul = df.iloc[2]
df_seoul
# Out:
# 행정구역(시군구)별     서울특별시
# 이동규모별              계
# 2001          -10031
# 2002          -13003
# 2003          -10568
# 2004          -10493
# 2005           -9106
# 2006            3507
# 2007           -4484
# 2008           -9770
# 2009           -9332
# 2010          -43713
# 2011          -44534
# 2012          -35079
# 2013          -34584
# 2014          -28750
# 2015          -54068
# 2016          -49971
# 2017          -28326
# 2018          -23218
# 2019            3868
# Name: 2, dtype: object

# %%
plt.plot(df_seoul.index[2:],df_seoul.values[2:])
plt.title('Seoul In/Out Population')
plt.xlabel('years')
plt.ylabel('people')
plt.show()
